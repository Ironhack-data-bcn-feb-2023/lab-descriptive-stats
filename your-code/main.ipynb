# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
import pandas as pd

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
temp = pd.read_csv('Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
temp_NY = temp[temp['State']== 'New York']

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
temp_NY.Temperature.mean()
# Out:
# 10.74074074074074

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
temp[temp.Temperature > 15]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
temp['City'][temp.Temperature > 15]
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
temp['City'][(temp.Temperature > 15) & (temp.Temperature < 20)]
# Out:
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
temp.groupby('State')['Temperature'].agg(['mean', 'std'])
# Out:
#                   mean       std
# State
# Connecticut  15.833333  1.964186
# New Jersey   21.111111  1.571348
# New York     10.740741  8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
employee = pd.read_csv('Employee.csv')

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %%
employee.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
import seaborn as sns

# %%
sns.histplot(data=employee, x='Salary', bins=5)
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %% [markdown]
# #### What's the average salary in this company?

# %%
employee.Salary.mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
employee.Salary.max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
min = employee.Salary.min()

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
employee[employee['Salary'] == min]['Name']
# Out:
# 1    Maria
# 2    David
# Name: Name, dtype: object

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
employee[employee['Name']=='David']
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
employee[employee['Name']=='David']['Salary']
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
employee[employee['Title']=='associate']
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
employee[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
employee[(employee['Title']=='associate') & (employee['Salary']>55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
employee.groupby('Years')['Salary'].agg(['mean'])
# Out:
#             mean
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
employee.groupby('Title')['Salary'].agg(['mean'])
# Out:
#                 mean
# Title
# VP         70.000000
# analyst    32.500000
# associate  56.666667

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
sns.boxplot(data=employee, x='Salary')
# Out:
# <Axes: xlabel='Salary'>

# %%
employee['Salary'].quantile(0.25)
# Out:
# 35.0

# %%
employee['Salary'].quantile(0.75)
# Out:
# 60.0

# %% [markdown]
# 50% of the salaries are between 35 and 60.

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
employee.groupby('Gender')['Salary'].agg(['mean'])
# Out:
#         mean
# Gender
# F       47.5
# M       50.0

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
employee.describe()
# Out:
#           Years     Salary
# count  9.000000   9.000000
# mean   4.111111  48.888889
# std    2.803767  16.541194
# min    1.000000  30.000000
# 25%    2.000000  35.000000
# 50%    3.000000  55.000000
# 75%    7.000000  60.000000
# max    8.000000  70.000000

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
employee.groupby('Title')['Salary'].apply(lambda x: x.max() - x.min())
# Out:
# Title
# VP           0
# analyst      5
# associate    5
# Name: Salary, dtype: int64

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
orders = pd.read_csv('Orders.zip')

# %%
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                       white metal lantern         6  2010-12-01 08:26:00
# 2            cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3       knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4            red woolly hottie white heart.         6  2010-12-01 08:26:00
# ...                                     ...       ...                  ...
# 397919          pack of 20 spaceboy napkins        12  2011-12-09 12:50:00
# 397920         children's apron dolly girl          6  2011-12-09 12:50:00
# 397921        childrens cutlery dolly girl          4  2011-12-09 12:50:00
# 397922      childrens cutlery circus parade         4  2011-12-09 12:50:00
# 397923        baking set 9 piece retrospot          3  2011-12-09 12:50:00
#
#         UnitPrice  CustomerID         Country  amount_spent
# 0            2.55       17850  United Kingdom         15.30
# 1            3.39       17850  United Kingdom         20.34
# 2            2.75       17850  United Kingdom         22.00
# 3            3.39       17850  United Kingdom         20.34
# 4            3.39       17850  United Kingdom         20.34
# ...           ...         ...             ...           ...
# 397919       0.85       12680          France         10.20
# 397920       2.10       12680          France         12.60
# 397921       4.15       12680          France         16.60
# 397922       4.15       12680          France         16.60
# 397923       4.95       12680          France         14.85
#
# [397924 rows x 14 columns]

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# 25%         2.000000      11.000000       2.000000       1.250000
# 50%         3.000000      13.000000       6.000000       1.950000
# 75%         5.000000      14.000000      12.000000       3.750000
# max         7.000000      20.000000   80995.000000    8142.750000
#
#           CustomerID   amount_spent
# count  397924.000000  397924.000000
# mean    15294.315171      22.394749
# std      1713.169877     309.055588
# min     12346.000000       0.000000
# 25%     13969.000000       4.680000
# 50%     15159.000000      11.800000
# 75%     16795.000000      19.800000
# max     18287.000000  168469.600000

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
orders['amount_spent'].agg(['mean'])
# Out:
# mean    22.394749
# Name: amount_spent, dtype: float64

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
orders['amount_spent'].max()
# Out:
# 168469.6

# %%
orders['amount_spent'].min()
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
orders['CustomerID'][orders['Country']=='Spain'].unique()
# Out:
# array([12557, 17097, 12540, 12551, 12484, 12539, 12510, 12421, 12502,
#        12462, 12507, 12541, 12547, 12597, 12545, 12596, 12354, 12417,
#        12455, 12450, 12548, 12556, 12550, 12546, 12454, 12448, 12544,
#        12538, 12445, 12442])

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
orders['CustomerID'][orders['Country']=='Spain'].nunique()
# Out:
# 30

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
unique_customers_above_50 = orders['CustomerID'].value_counts()[orders['CustomerID'].value_counts() > 50].index.tolist()

print(unique_customers_above_50)
# Out:
# [17841, 14911, 14096, 12748, 14606, 15311, 14646, 13089, 13263, 14298, 15039, 14156, 18118, 14159, 14796, 16033, 15005, 14056, 14769, 13081, 16549, 14527, 14456, 17511, 15719, 15555, 16931, 17811, 14505, 18283, 17338, 17757, 12921, 12415, 16904, 15159, 16764, 17675, 13137, 15547, 17920, 17735, 16923, 15529, 16241, 16360, 16729, 15856, 12681, 13969, 16713, 14502, 13230, 14415, 14088, 16686, 14194, 17611, 14667, 13098, 13694, 17238, 15023, 17602, 15993, 15358, 16910, 15861, 17337, 17231, 12867, 12682, 14367, 14534, 15356, 17059, 15498, 15033, 15998, 14730, 17346, 14895, 14049, 17954, 15640, 17139, 13408, 12540, 13319, 16161, 17315, 15021, 18041, 17220, 13668, 18069, 17365, 12621, 15867, 12471, 16558, 13018, 15044, 14085, 16813, 16746, 16712, 12567, 18109, 13451, 15078, 17581, 13268
725, 15416, 12417, 15298, 18022, 12553, 15858, 13736, 12449, 16743, 16782, 17790, 18172, 16818, 12569, 13634, 15484, 13285, 17085, 13266, 16401, 14388, 15521, 16726, 15622, 15955, 17341, 16525, 16015, 16469, 12347, 15009, 14401, 14083, 17472, 13184, 12955, 16059, 15764, 14461, 14307, 16200, 13536, 16626, 17974, 13881, 15514, 15525, 16880, 13772, 16533, 12444, 15974, 13015, 13566, 13815, 18245, 13558, 12836, 14227, 16442, 13588, 13838, 17073, 15738, 14639, 16607, 13381, 13523, 16407, 13047, 14004, 12688, 15696, 16470, 13139, 16755, 14669, 14944, 17001, 16511, 17837, 14662, 15574, 12562, 12 ...

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
orders[(orders['Country'] == 'Spain') & (orders['Quantity'] > 50)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# 174444      248799     558871     20725  2011      7    1    13
# 174445      248800     558871     20728  2011      7    1    13
# 174446      248801     558871    84997B  2011      7    1    13
# 174447      248802     558871    84997D  2011      7    1    13
# 174448      248803     558871    84997C  2011      7    1    13
# 174449      248804     558871    84997A  2011      7    1    13
# 197167      282906     561669     23295  2011      7    4    17
# 197168      282907     561669     23297  2011      7    4    17
# 197169      282908     561669     23294  2011      7    4    17
# 197170      282909     561669     23296  2011      7    4    17
# 197171      282910     561669     23293  2011      7    4    17
# 224881      315702     564734     84826  2011      8    7    13
# 254097      355752     567968     85204  2011      9    5     9
# 289129      398626     571255    82494L  2011     10    5    17
# 289134      398631     571255     82482  2011     10    5    17
# 289142      398639     571255    72802B  2011     10    5    17
# 289143      398640     571255    72802C  2011     10    5    17
# 295956      407272     571851     23167  2011     10    3    13
# 312655      426665     573362     22598  2011     10    7    13
# 312656      426666     573362     22597  2011     10    7    13
# 312657      426667     573362     22599  2011     10    7    13
# 366326      495739     578321     20728  2011     11    3    16
# 366327      495740     578321    84997B  2011     11    3    16
# 366328      495741     578321    84997D  2011     11    3    16
# 366329      495742     578321    84997C  2011     11    3    16
#
#                                 Description  Quantity          InvoiceDate  \
# 4250                lunch bag suki  design         70  2010-12-03 12:20:00
# 4251                lunch bag pink polkadot       100  2010-12-03 12:20:00
# 4252                lunch bag  black skull.        60  2010-12-03 12:20:00
# 4253                lunch bag red retrospot        70  2010-12-03 12:20:00
# 4254                    lunch bag cars blue       100  2010-12-03 12:20:00
# 208950        0.0       14911            EIRE           0.0
# 223931        0.0       14646     Netherlands           0.0
# 223932        0.0       14646     Netherlands           0.0
# 223933        0.0       14646     Netherlands           0.0
# 223934        0.0       14646     Netherlands           0.0
# 256263        0.0       16133  United Kingdom           0.0
# 259399        0.0       12748  United Kingdom           0.0
# 273926        0.0       15804  United Kingdom           0.0
# 286507        0.0       12446             RSA           0.0
# 307092        0.0       18059  United Kingdom           0.0
# 319882        0.0       12415       Australia           0.0
# 320049        0.0       14110  United Kingdom           0.0
# 320407        0.0       12437          France           0.0
# 322279        0.0       12431       Australia           0.0
# 328385        0.0       13014  United Kingdom           0.0
# 329006        0.0       13985  United Kingdom           0.0
# 329007        0.0       13985  United Kingdom           0.0
# 334242        0.0       13081  United Kingdom           0.0
# 334243        0.0       13081  United Kingdom           0.0
# 352746        0.0       15602  United Kingdom           0.0
# 353097        0.0       12603         Germany           0.0
# 354170        0.0       12444          Norway           0.0
# 358629        0.0       16406  United Kingdom           0.0
# 370473        0.0       13256  United Kingdom           0.0

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
orders[orders['Description'].str.contains('lunch bag', case=False)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# 172     lunch bag dolly girl design        10  2010-12-01 09:56:00       1.65
# 354     lunch bag dolly girl design         1  2010-12-01 11:21:00       1.65
# 359         lunch bag red retrospot         1  2010-12-01 11:21:00       1.65
# 360      lunch bag spaceboy design          2  2010-12-01 11:21:00       1.65
# ...                             ...       ...                  ...        ...
# 397465    lunch bag alphabet design        10  2011-12-09 09:38:00       1.65
# 397713      lunch bag  black skull.         1  2011-12-09 11:34:00       1.65
# 397714      lunch bag red retrospot         1  2011-12-09 11:34:00       1.65
# 397877  lunch bag red vintage doily        10  2011-12-09 12:20:00       1.65
# 397880      lunch bag red retrospot        40  2011-12-09 12:23:00       1.45
#
#         CustomerID         Country  amount_spent
# 93           14688  United Kingdom         16.50
# 172          17420  United Kingdom         16.50
# 354          15862  United Kingdom          1.65
# 359          15862  United Kingdom          1.65
# 360          15862  United Kingdom          3.30
# ...            ...             ...           ...
# 397465       17001  United Kingdom         16.50
# 397713       14446  United Kingdom          1.65
# 397714       14446  United Kingdom          1.65
# 397877       17581  United Kingdom         16.50
# 397880       13777  United Kingdom         58.00
#
# [11556 rows x 14 columns]

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
orders['InvoiceDate'] = pd.to_datetime(orders['InvoiceDate'])
orders[(orders['Description'].str.contains('lunch bag', case=False)) & (orders['InvoiceDate'].dt.year == 2011)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity         InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10 2011-01-04 11:40:00       1.65
# 26341            lunch bag woodland        10 2011-01-04 11:40:00       1.65
# 26512    lunch bag spaceboy design          2 2011-01-04 12:58:00       1.65
# 26513            lunch bag woodland         1 2011-01-04 12:58:00       1.65
# 26860       lunch bag pink polkadot         1 2011-01-04 15:50:00       1.65
# ...                             ...       ...                 ...        ...
# 397465    lunch bag alphabet design        10 2011-12-09 09:38:00       1.65
# 397713      lunch bag  black skull.         1 2011-12-09 11:34:00       1.65
# 397714      lunch bag red retrospot         1 2011-12-09 11:34:00       1.65
# 397877  lunch bag red vintage doily        10 2011-12-09 12:20:00       1.65
# 397880      lunch bag red retrospot        40 2011-12-09 12:23:00       1.45
#
#         CustomerID         Country  amount_spent
# 26340        13319  United Kingdom         16.50
# 26341        13319  United Kingdom         16.50
# 26512        15039  United Kingdom          3.30
# 26513        15039  United Kingdom          1.65
# 26860        16241  United Kingdom          1.65
# ...            ...             ...           ...
# 397465       17001  United Kingdom         16.50
# 397713       14446  United Kingdom          1.65
# 397714       14446  United Kingdom          1.65
# 397877       17581  United Kingdom         16.50
# 397880       13777  United Kingdom         58.00
#
# [11234 rows x 14 columns]

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %% [markdown]
# #### Select all orders made in the month of August

# %%
orders[orders['InvoiceDate'].dt.month == 8]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity         InvoiceDate  \
# 199475         6 ribbons elegant christmas         96 2011-08-01 08:30:00
# 199476            scandinavian reds ribbons       156 2011-08-01 08:30:00
# 199477      ivory hanging decoration  heart        24 2011-08-01 09:31:00
# 199478     single heart zinc t-light holder        12 2011-08-01 09:31:00
# 199479    hanging heart zinc t-light holder        12 2011-08-01 09:31:00
# ...                                     ...       ...                 ...
# 226483       ceramic cherry cake money bank         2 2011-08-31 17:16:00
# 226484  ceramic heart fairy cake money bank         2 2011-08-31 17:16:00
# 226485                piggy bank retrospot          2 2011-08-31 17:16:00
# 226486   ceramic strawberry cake money bank         2 2011-08-31 17:16:00
# 226487                       funky diva pen        48 2011-08-31 17:16:00
#
#         UnitPrice  CustomerID         Country  amount_spent
# 199475       1.45       17941  United Kingdom        139.20
# 199476       1.06       17941  United Kingdom        165.36
# 199477       0.85       14947  United Kingdom         20.40
# 199478       0.95       14947  United Kingdom         11.40
# 199479       0.85       14947  United Kingdom         10.20
# ...           ...         ...             ...           ...
# 226483       1.45       15856  United Kingdom          2.90
# 226484       1.45       15856  United Kingdom          2.90
# 226485       2.55       15856  United Kingdom          5.10
# 226486       1.45       15856  United Kingdom          2.90
# 226487       0.85       15856  United Kingdom         40.80
#
# [27013 rows x 14 columns]

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
orders_august = orders[orders['InvoiceDate'].dt.month == 8]
order_count_by_country = orders_august['Country'].value_counts()

print(order_count_by_country)
# Out:
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: Country, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
orders.groupby('Country')['amount_spent'].agg('mean')
# Out:
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# Poland                   22.226212
# Portugal                 22.872702
# RSA                      17.281207
# Saudi Arabia             16.213333
# Singapore                95.852658
# Spain                    24.779521
# Sweden                   85.096075
# Switzerland              30.642752
# USA                      20.002179
# United Arab Emirates     27.974706
# United Kingdom           20.625073
# Unspecified              10.930615
# Name: amount_spent, dtype: float64

# %% [markdown]
# #### What's the most expensive item?

# %%
orders[orders['UnitPrice']==orders['UnitPrice'].max()][['Description', 'UnitPrice']]
# Out:
#        Description  UnitPrice
# 118352     postage    8142.75

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
orders.groupby('year')['amount_spent'].agg('mean')
# Out:
# year
# 2010    21.892733
# 2011    22.430074
# Name: amount_spent, dtype: float64
